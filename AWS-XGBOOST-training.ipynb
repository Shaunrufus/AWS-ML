# %%
pip install xgboost
# Out:
# ...
#   Using cached xgboost-3.0.2-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/150.0 MB 1.3 MB/s eta 0:01:59
#    ---------------------------------------- 0.8/150.0 MB 1.3 MB/s eta 0:01:56
#    ---------------------------------------- 1.0/150.0 MB 1.3 MB/s eta 0:01:52
#    ---------------------------------------- 1.3/150.0 MB 1.3 MB/s eta 0:01:52
#    ---------------------------------------- 1.6/150.0 MB 1.4 MB/s eta 0:01:46
#    ---------------------------------------- 1.8/150.0 MB 1.4 MB/s eta 0:01:48
#     --------------------------------------- 2.1/150.0 MB 1.4 MB/s eta 0:01:49
#     --------------------------------------- 2.4/150.0 MB 1.3 MB/s eta 0:01:50
# ...

# %%
import xgboost as xgb

# Load the model file 
model = xgb.Booster()
model.load_model("xgboost-model")

# %%
#prediction

import pandas as pd
import xgboost as xgb

# Example dummy input (you should load your real dataset here)
df = pd.DataFrame({
    'feature1': [0.1],
    'feature2': [1.5],
    'feature3': [3.2],
    # Add all required features...
})

# Convert to DMatrix
dmat = xgb.DMatrix(df)

# Predict
prediction = model.predict(dmat)
print("Prediction:", prediction)
# Out:
# Prediction: [1632.7155]

# %%
import xgboost as xgb

model = xgb.Booster()
try:
    model.load_model("xgboost-model")  
    print("Loaded as Booster!")
except:
    print("Failed to load as Booster.")

from xgboost import XGBClassifier
model2 = XGBClassifier()
try:
    model2.load_model("xgboost-model")  
    print("Loaded as XGBClassifier!")
except:
    print("Failed to load as XGBClassifier.")
# Out:
# Loaded as Booster!
# Loaded as XGBClassifier!

# %%
import pandas as pd
import xgboost as xgb
from xgboost import XGBRegressor

# Load test data
df = pd.read_csv("C:\ML Projects\ML datasets\insurancecharges.csv")

# One-hot encode categorical columns
df_encoded = pd.get_dummies(df)

# Drop target column if present (like 'charges')
X_new = df_encoded.drop("charges", axis=1, errors='ignore')

# Load the trained XGBoost model
model = XGBRegressor()
model.load_model("xgboost-model")  

# Make predictions
predictions = model.predict(X_new)

# Show results
print("Predictions:", predictions)
# Out:
# Predictions: [16176.369    555.0557   555.0557 ... 11065.762  10895.674  16008.802 ]
# <>:6: SyntaxWarning: invalid escape sequence '\M'
# <>:6: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\shaun\AppData\Local\Temp\ipykernel_24180\175049504.py:6: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("C:\ML Projects\ML datasets\insurancecharges.csv")

# %%
# --------------------------------------------
# Step 4: Model Training using XGBoost Estimator (SageMaker)
# --------------------------------------------

# In SageMaker Studio, I used the built-in XGBoost Estimator to train the model.
# The training script was run automatically and the model was saved as model.tar.gz

# The estimator would look something like this (not run locally):

from sagemaker.estimator import Estimator

xgb_estimator = Estimator(
    image_uri=sagemaker.image_uris.retrieve("xgboost", region, version="1.3-1"),
    role=sagemaker_role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    output_path=s3_output_path,
    base_job_name="xgboost-insurance"
)

xgb_estimator.set_hyperparameters(
    objective="reg:squarederror",
    num_round=100
)

xgb_estimator.fit({"train": train_input, "validation": validation_input})

# %% [markdown]
# ### Model Training (SageMaker)
#
# The model was trained using the built-in XGBoost Estimator in SageMaker. The dataset was uploaded to S3 and passed to the Estimator via the `.fit()` method.
#
# The resulting model artifact (model.tar.gz) was saved in S3 and later downloaded for local inference using the `XGBRegressor().load_model()` method.
#
# Note: Since training was handled through AWS infrastructure, explicit training code is not present in this notebook but was handled in a different notebook/job run.
